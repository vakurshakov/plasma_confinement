# %%
field_at = []
with open("field_at.txt", 'r') as f:
    TIME = (int)(f.readline())
    for t in range(TIME):
        field_at.append((float)(f.readline()))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from scipy.fftpack import rfft, rfftfreq
import datetime

f_t = np.asarray(field_at[:])
    
f_w = rfft(f_t)
w = rfftfreq(TIME)*2*np.pi

fig = plt.figure(figsize=(10,12))
ax1 = fig.add_subplot(211); ax1.set_title('Ex(t)')
ax2 = fig.add_subplot(212); ax2.set_title('Ex(w)')

f_t_ = ax1.plot(range(TIME), field_at)
f_w_ = ax2.plot(w, np.abs(f_w)/len(f_w))

now = datetime.datetime.now()
fig.savefig("evolution of heated plasma, ref. boundaries (" + now.strftime('%Y%m%d, %H_%M') + ").png")
